# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import tree
input_file = "E:\Machine Learning Workshop\HCV Egyptian Patients\HCV Egyptian Patients\HCV-Egy-Data.csv"
dataset = pd.read_csv(input_file, header = 0)
df = dataset.iloc[:,[14,15,16,17,18,19,20,21,8]]

# %%
df
# Out:
#       AST 1  ALT 1   ALT4  ALT 12  ALT 24  ALT 36  ALT 48  ALT after 24 w  \
# 0        99     84   52.0     109      81       5       5               5
# 1        91    123   95.0      75     113      57     123              44
# 2       113     49   95.0     107     116       5       5               5
# 3        43     64  109.0      80      88      48      77              33
# 4        99    104   67.0      48     120      94      90              30
# ...     ...    ...    ...     ...     ...     ...     ...             ...
# 1380    122     59   78.0     106     127      63      44              45
# 1381    128    102   65.0      99     108      97      64              41
# 1382     61     93  123.0      61     116      87      39              24
# 1383     70     97  104.0      74      47      48      81              43
# 1384     51    126   39.0      68     115      64      71              34
#
#       Jaundice
# 0             2
# 1             2
# 2             1
# ...

# %%
data = df.drop(["Jaundice "],axis=1)
data
# Out:
#       AST 1  ALT 1   ALT4  ALT 12  ALT 24  ALT 36  ALT 48  ALT after 24 w
# 0        99     84   52.0     109      81       5       5               5
# 1        91    123   95.0      75     113      57     123              44
# 2       113     49   95.0     107     116       5       5               5
# 3        43     64  109.0      80      88      48      77              33
# 4        99    104   67.0      48     120      94      90              30
# ...     ...    ...    ...     ...     ...     ...     ...             ...
# 1380    122     59   78.0     106     127      63      44              45
# 1381    128    102   65.0      99     108      97      64              41
# 1382     61     93  123.0      61     116      87      39              24
# 1383     70     97  104.0      74      47      48      81              43
# 1384     51    126   39.0      68     115      64      71              34
#
# [1385 rows x 8 columns]

# %%
A = data.values
for i,items in enumerate(A):
    for j,item in enumerate(items):
        if (item>0 and item<20):
            A[i,j] = 0 
        elif (item>20 and item<40): 
            A[i,j] = 1
        elif (item>40 and item<128):
            A[i,j] = 2

# %%
A
# Out:
# array([[2., 2., 2., ..., 0., 0., 0.],
#        [2., 2., 2., ..., 2., 2., 2.],
#        [2., 2., 2., ..., 0., 0., 0.],
#        ...,
#        [2., 2., 2., ..., 2., 1., 1.],
#        [2., 2., 2., ..., 2., 2., 2.],
#        [2., 2., 1., ..., 2., 2., 1.]])

# %%
features = list(data.columns[:8])
features
# Out:
# ['AST 1',
#  'ALT 1',
#  'ALT4',
#  'ALT 12',
#  'ALT 24',
#  'ALT 36',
#  'ALT 48',
#  'ALT after 24 w']

# %%
y = df["Jaundice "]
X = df[features]
clf = tree.DecisionTreeClassifier(min_samples_leaf= 1, min_samples_split = 2)
clf = clf.fit(X,y)
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
import pydotplus

dot_data = StringIO()  
tree.export_graphviz(clf, out_file=dot_data,  
                         feature_names=features)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# C:\Users\Anudit\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, y)
print (clf.predict([[0, 1, 0, 0, 0, 1, 1, 2]]))
print (clf.predict([[1, 1, 1, 1, 0, 2, 1, 2]]))
# Out:
# [1]
# [1]
